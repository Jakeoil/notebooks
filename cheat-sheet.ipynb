# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Make a table

# %%
df = pd.DataFrame (data=np.array([[1,2,3],[4,5,6]], dtype=int), columns=['A','B','C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %%
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20190101', periods=6)
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2019-01-01 -0.558602  0.813656 -0.003913  0.386560
# 2019-01-02 -0.188020  1.091665 -1.599695  0.038999
# 2019-01-03 -1.656308  0.174458  0.925719 -0.630484
# 2019-01-04  0.102130  0.839226  0.671889  1.060024
# 2019-01-05 -1.139960  0.189386  0.717814 -0.349665
# 2019-01-06  1.388109 -1.855220  0.084463 -0.057137

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                   'B': pd.Timestamp('20190123'),
                   'C': pd.Series(1,index=list(range(4)),dtype='float32'),
                   'D': np.array([3] * 4,dtype='int32'),
                   'E': pd.Categorical(["test","train","test","train"]),
                   'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2019-01-23  1.0  3   test  foo
# 1  1.0 2019-01-23  1.0  3  train  foo
# 2  1.0 2019-01-23  1.0  3   test  foo
# 3  1.0 2019-01-23  1.0  3  train  foo

# %% [markdown]
# The columns of the resulting DataFrame have different dtypes.

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# If you're using IPython, tab compleation for column names(as well as public attribures) is automatically enabled. Here's a subset of the attributes that will be completed:

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import time
time.sleep(100)

# %%
def say_hello(recipient):
    return 'Hello, {}!'.format(recipient)
say_hello('Chicago')
# Out:
# 'Hello, Chicago!'

# %% [markdown]
# Now this is a Markdown cell

# %% [markdown]
# # This is a level 1 heading
# ## This is a level 2 heading
# This is some plain text that forms a paragraph.
# Add emphasis via **bold** and __bold__, or *italic* and _italic_.
#
# Paragraphs must be separated by an empty line
#
# * Sometimes we want to include lists.
#  * Which can be indented.
#
# 1. Lists can also be numbered
# 2. For ordered lists.
#
# [It is possible to include hyperlinks](https://jakeoil.net)
#
# Inline code uses single backticks: `foo()`, and code blocks use triple backticks:
#
# ```
# bar
# ```
#
# Code can be indented by 4 spaces.
#
# ### Let them eat cake

# %% [markdown]
# Mermaid cake by Debbie
# ![Mermaid cake](http://jakeoil.net/deeko/cake/images/IMG_4653.JPG)
# >This is my favorite cake.  There are scores more.

# %% [markdown]
# This is an H1
# ======
#
#
# *   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.
#     Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi,
#     viverra nec, fringilla in, laoreet vitae, risus.
# *   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.
#     Suspendisse id sem consectetuer libero luctus adipiscing.
#
#
# *   Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.
# *   Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse id sem consectetuer libero luctus adipiscing.

# %% [markdown]
# ### Kernals

# %%
# We already have np
import numpy as np
def square(x):
    return x * x

# %%
for i in range(6):
    x = np.random.randint(1,10)
    y = square(x)
    print('%d squared is %d' % (x, y))
# Out:
# 5 squared is 25
# 1 squared is 1
# 3 squared is 9
# 4 squared is 16
# 4 squared is 16
# 5 squared is 25

# %% [markdown]
# The fortune 500 csv is in the local directory

# %%
#%matplitlib inline
import seaborn as sns
sns.set(style="darkgrid")
df = pd.read_csv('fortune500.csv')

# %%
df.head()
# Out:
#    Year  Rank           Company  Revenue (in millions) Profit (in millions)
# 0  1955     1    General Motors                 9823.5                  806
# 1  1955     2       Exxon Mobil                 5661.4                584.8
# 2  1955     3        U.S. Steel                 3250.4                195.4
# 3  1955     4  General Electric                 2959.1                212.6
# 4  1955     5            Esmark                 2510.8                 19.1

# %%
df.tail()
# Out:
#        Year  Rank                Company  Revenue (in millions)  \
# 25495  2005   496        Wm. Wrigley Jr.                 3648.6
# 25496  2005   497         Peabody Energy                 3631.6
# 25497  2005   498  Wendy's International                 3630.4
# 25498  2005   499     Kindred Healthcare                 3616.6
# 25499  2005   500   Cincinnati Financial                 3614.0
#
#       Profit (in millions)
# 25495                  493
# 25496                175.4
# 25497                 57.8
# 25498                 70.6
# 25499                  584

# %%
df.columns = ['year','rank', 'company', 'revenue', 'profit']
df.head()
# Out:
#    year  rank           company  revenue profit
# 0  1955     1    General Motors   9823.5    806
# 1  1955     2       Exxon Mobil   5661.4  584.8
# 2  1955     3        U.S. Steel   3250.4  195.4
# 3  1955     4  General Electric   2959.1  212.6
# 4  1955     5            Esmark   2510.8   19.1

# %%
len(df)
# Out:
# 25500

# %%
df.dtypes
# Out:
# year         int64
# rank         int64
# company     object
# revenue    float64
# profit      object
# dtype: object

# %%
non_numeric_profits = df.profit.str.contains('[^0-9.-]')
non_numeric_profits
df.loc[non_numeric_profits]
# Out:
#        year  rank                           company   revenue profit
# 228    1955   229                            Norton     135.0   N.A.
# 290    1955   291                   Schlitz Brewing     100.0   N.A.
# 294    1955   295             Pacific Vegetable Oil      97.9   N.A.
# 296    1955   297                Liebmann Breweries      96.0   N.A.
# 352    1955   353                Minneapolis-Moline      77.4   N.A.
# 464    1955   465                   Gilfillan Bros.      54.0   N.A.
# 712    1956   213                            Norton     160.5   N.A.
# 857    1956   358                Liebmann Breweries      83.0   N.A.
# 1225   1957   226                            Norton     173.0   N.A.
# 1372   1957   373                Liebmann Breweries      90.0   N.A.
# 1419   1957   420        Crowell-Collier Publishing      74.8   N.A.
# 1717   1958   218  Hearst Consolidated Publications     195.7   N.A.
# 1738   1958   239                            Norton     176.8   N.A.
# ...

# %%
set(df.profit[non_numeric_profits])
# Out:
# {'N.A.'}

# %%
len(df.profit[non_numeric_profits])
# Out:
# 369

# %%
bin_sizes, _, _ = plt.hist(df.year[non_numeric_profits], bins=range(1955,2006))

# %%
df = df.loc[~non_numeric_profits]
df.profit = df.profit.apply(pd.to_numeric)
len(df)
# Out:
# 25131

# %%
df.dtypes
# Out:
# year         int64
# rank         int64
# company     object
# revenue    float64
# profit     float64
# dtype: object

# %%
group_by_year = df.loc[:,['year','revenue','profit']].groupby('year')
avgs = group_by_year.mean()
x = avgs.index
y1 = avgs.profit
avgs
# Out:
#            revenue       profit
# year
# 1955    275.754453    16.732186
# 1956    323.604418    22.509237
# 1957    350.037626    23.181087
# 1958    377.977264    23.456740
# 1959    355.229376    19.279276
# 1960    395.231864    24.019439
# 1961    410.552410    23.340361
# 1962    419.556827    23.326104
# 1963    458.164200    26.965000
# 1964    490.181600    29.675800
# 1965    533.858517    34.543287
# 1966    596.118200    40.023000
# 1967    665.160800    44.155400
# 1968    717.771600    42.801200
# 1969    810.546400    48.387400
# 1970    889.436400    49.354800
# 1971    930.380122    43.952535
# 1972   1013.868699    47.585569
# 1973   1122.406085    56.448479
# 1974   1342.981744    78.461460
# 1975   1674.533401    88.345547
# 1976   1740.684178    76.774645
# 1977   1953.818256   100.138742
# 1978   2190.829532   107.128921
# 1979   2455.912220   125.347862
# 1980   2907.460446   158.932049
# 1981   3322.324797   165.021748
# 1982   3578.050000   171.926327
# ...

# %%
x
# Out:
# Int64Index([1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#             1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#             1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#             1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#             1999, 2000, 2001, 2002, 2003, 2004, 2005],
#            dtype='int64', name='year')

# %%
y1
# Out:
# year
# 1955      16.732186
# 1956      22.509237
# 1957      23.181087
# 1958      23.456740
# 1959      19.279276
# 1960      24.019439
# 1961      23.340361
# 1962      23.326104
# 1963      26.965000
# 1964      29.675800
# 1965      34.543287
# 1966      40.023000
# 1967      44.155400
# 1968      42.801200
# 1969      48.387400
# 1970      49.354800
# 1971      43.952535
# 1972      47.585569
# 1973      56.448479
# 1974      78.461460
# 1975      88.345547
# 1976      76.774645
# 1977     100.138742
# 1978     107.128921
# 1979     125.347862
# 1980     158.932049
# 1981     165.021748
# 1982     171.926327
# 1983     125.104684
# 1984     140.670143
# 1985     176.473306
# 1986     145.980294
# 1987     134.419916
# 1988     188.693750
# 1989     241.518908
# 1990     219.716632
# 1991     194.674583
# 1992     114.938622
# 1993      -0.405165
# 1994     129.387810
# 1995     435.736640
# 1996     493.942105
# 1997     606.676815
# 1998     652.375050
# 1999     672.704628
# ...

# %%
def plot(x,y,ax,title,y_label):
    ax.set_title(title)
    ax.set_ylabel(y_label)
    ax.plot(x,y)
    ax.margins(x=0,y=0)
    
fig,ax = plt.subplots()
plot(x,y1,ax,'Increase', 'Profits')

# %%
import ipywidgets as widgets
slider = widgets.IntSlider()
button = widgets.Button(description='Button')
button
#from IPython.display import display
#slider
# Out:
# Button(description='Button', style=ButtonStyle())

# %%
slider
# Out:
# IntSlider(value=0)

# %%
dir(slider)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_notifiers',
#  '_call_widget_constructed',
#  '_comm_changed',
#  '_compare',
#  '_cross_validation_lock',
#  '_default_keys',
#  '_display_callbacks',
#  '_dom_classes',
#  '_gen_repr_from_keys',
#  '_get_embed_state',
#  '_handle_custom_msg',
#  '_handle_displayed',
#  '_handle_msg',
#  '_holding_sync',
#  '_ipython_display_',
#  '_is_numpy',
#  '_lock_property',
#  '_log_default',
#  '_model_id',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_msg_callbacks',
#  '_notify_trait',
# ...

# %%
slider.value
# Out:
# 0

# %%
slider.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']
